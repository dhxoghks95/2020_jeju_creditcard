# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
data = pd.read_csv('C:/Users/USER/Desktop/[2020]/2020 summer/데이콘/jeju_data_ver1/201901-202003.csv')

<<<<<도 성별 나이 벨류>>>>>

# %%
data.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %%
data
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 0           201901           강원         강릉시  건강보조식품 소매업          강원
# 1           201901           강원         강릉시  건강보조식품 소매업          강원
# 2           201901           강원         강릉시  건강보조식품 소매업          강원
# 3           201901           강원         강릉시  건강보조식품 소매업          강원
# 4           201901           강원         강릉시  건강보조식품 소매업          강원
# ...            ...          ...         ...         ...         ...
# 24697787    202003           충북         충주시    휴양콘도 운영업          충북
# 24697788    202003           충북         충주시    휴양콘도 운영업          충북
# 24697789    202003           충북         충주시    휴양콘도 운영업          충북
# 24697790    202003           충북         충주시    휴양콘도 운영업          충북
# 24697791    202003           충북         충주시    휴양콘도 운영업          충북
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0               강릉시  20s            1    1          4   311200    4
# ...

# %%
data.tail()
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 24697787    202003           충북         충주시    휴양콘도 운영업          충북
# 24697788    202003           충북         충주시    휴양콘도 운영업          충북
# 24697789    202003           충북         충주시    휴양콘도 운영업          충북
# 24697790    202003           충북         충주시    휴양콘도 운영업          충북
# 24697791    202003           충북         충주시    휴양콘도 운영업          충북
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT     AMT  CNT
# 24697787        충주시  30s            1    2          3   43300    4
# 24697788        충주시  40s            1    3          3   35000    3
# 24697789        충주시  50s            1    4          4  188000    6
# 24697790        충주시  50s            2    4          4   99000    6
# 24697791        충주시  60s            1    5          3  194000    3

# %%
data1 = pd.read_csv('C:/Users/USER/Desktop/2020 summer dacon/2020_jeju_credit card/data/행정구역_시_별_연령별_인구수_202004.csv',encoding='cp949')

# %%
data1.head()
# Out:
#                   행정구역 2020년04월_거주자_총인구수 2020년04월_거주자_연령구간인구수  \
# 0     전국  (0000000000)        51,351,759           51,351,759
# 1  서울특별시  (1100000000)         9,561,199            9,561,199
# 2  부산광역시  (2600000000)         3,371,973            3,371,973
# 3  대구광역시  (2700000000)         2,413,738            2,413,738
# 4  인천광역시  (2800000000)         2,923,071            2,923,071
#
#   2020년04월_거주자_0~9세 2020년04월_거주자_10~19세 2020년04월_거주자_20~29세  \
# 0         4,101,282           4,877,023           6,771,934
# 1           650,826             803,250           1,451,810
# 2           239,821             278,455             433,167
# 3           185,071             232,076             321,484
# 4           237,418             278,422             403,226
#
#   2020년04월_거주자_30~39세 2020년04월_거주자_40~49세 2020년04월_거주자_50~59세  \
# 0           6,940,217           8,266,552           8,544,542
# 1           1,483,018           1,524,792           1,499,315
# ...

# %% [markdown]
# 2019.01-2020.03 SIDO - CCG 별 인구수

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1 = data1.set_index('행정구역', drop = True)
data1
# Out:
#                       2020년04월_거주자_총인구수 2020년04월_거주자_연령구간인구수  \
# 행정구역
# 전국  (0000000000)             51,351,759           51,351,759
# 서울특별시  (1100000000)           9,561,199            9,561,199
# 부산광역시  (2600000000)           3,371,973            3,371,973
# 대구광역시  (2700000000)           2,413,738            2,413,738
# 인천광역시  (2800000000)           2,923,071            2,923,071
# 광주광역시  (2900000000)           1,447,260            1,447,260
# 대전광역시  (3000000000)           1,461,364            1,461,364
# 울산광역시  (3100000000)           1,138,123            1,138,123
# 세종특별자치시  (3600000000)           344,067              344,067
# 경기도  (4100000000)            13,197,973           13,197,973
# 강원도  (4200000000)             1,524,275            1,524,275
# 충청북도  (4300000000)            1,586,560            1,586,560
# 충청남도  (4400000000)            2,104,150            2,104,150
# 전라북도  (4500000000)            1,799,992            1,799,992
# ...

# %%
# 전국 단위 삭제
data1 = data1.drop(['전국  (0000000000)'])

# %%
# 도 이름 변경
data1.rename(index = {"서울특별시  (1100000000)" : '서울',
"부산광역시  (2600000000)" : '부산',
"대구광역시  (2700000000)" : '대구',
"인천광역시  (2800000000)" : '인천',
"광주광역시  (2900000000)" : '광주',
"대전광역시  (3000000000)" : '대전',
"울산광역시  (3100000000)" : '울산',
"세종특별자치시  (3600000000)" : '세종',
"경기도  (4100000000)" : '경기',
"강원도  (4200000000)" : '강원',
"충청북도  (4300000000)" : '충북',
"충청남도  (4400000000)" : '충남',
"전라북도  (4500000000)" : '전북',
"전라남도  (4600000000)" : '전남',
"경상북도  (4700000000)" : '경북',
"경상남도  (4800000000)" : '경남',
"제주특별자치도  (5000000000)" : '제주'
}, inplace = True)
data1
# Out:
#      2020년04월_거주자_총인구수 2020년04월_거주자_연령구간인구수 2020년04월_거주자_0~9세  \
# 행정구역
# 서울           9,561,199            9,561,199           650,826
# 부산           3,371,973            3,371,973           239,821
# 대구           2,413,738            2,413,738           185,071
# 인천           2,923,071            2,923,071           237,418
# 광주           1,447,260            1,447,260           124,372
# 대전           1,461,364            1,461,364           119,367
# 울산           1,138,123            1,138,123           102,565
# 세종             344,067              344,067            47,388
# 경기          13,197,973           13,197,973         1,172,075
# 강원           1,524,275            1,524,275           108,045
# 충북           1,586,560            1,586,560           127,195
# 충남           2,104,150            2,104,150           178,492
# 전북           1,799,992            1,799,992           133,918
# 전남           1,844,731            1,844,731           136,575
# ...

# %%
# 2020년04월_거주자_총인구수,2020년04월_거주자_연령구간인구수 삭제

data1 = data1.drop(['2020년04월_거주자_총인구수','2020년04월_거주자_연령구간인구수','2020년04월_남_거주자_총인구수','2020년04월_남_거주자_연령구간인구수','2020년04월_여_거주자_총인구수','2020년04월_여_거주자_연령구간인구수'], axis = 1)

# %%
# 간단하게 행 인덱스도 변경
data1.rename(columns = {"2020년04월_거주자_0~9세":'pop_0s',
                      "2020년04월_거주자_10~19세":'pop_10s',
                      "2020년04월_거주자_20~29세":'pop_20s',
                      "2020년04월_거주자_30~39세":'pop_30s',
                      "2020년04월_거주자_40~49세":'pop_40s',
                      "2020년04월_거주자_50~59세":'pop_50s',
                      "2020년04월_거주자_60~69세":'pop_60s',
                      "2020년04월_거주자_70~79세":'pop_70s',
                      "2020년04월_거주자_80~89세":'pop_80s',
                      "2020년04월_거주자_90~99세":'pop_90s',
                      "2020년04월_거주자_100세 이상":'pop_100s',
                      "2020년04월_남_거주자_0~9세":'pop_man_0s',
                      "2020년04월_남_거주자_10~19세":'pop_man_10s',
                      "2020년04월_남_거주자_20~29세":'pop_man_20s',
                      "2020년04월_남_거주자_30~39세":'pop_man_30s',
                      "2020년04월_남_거주자_40~49세":'pop_man_40s',
                      "2020년04월_남_거주자_50~59세":'pop_man_50s',
                      "2020년04월_남_거주자_60~69세":'pop_man_60s',
                      "2020년04월_남_거주자_70~79세":'pop_man_70s',
                      "2020년04월_남_거주자_80~89세":'pop_man_80s',
                      "2020년04월_남_거주자_90~99세":'pop_man_90s',
                      "2020년04월_남_거주자_100세 이상":'pop_man_100s',
                      "2020년04월_여_거주자_0~9세":'pop_woman_0s',
                      "2020년04월_여_거주자_10~19세":'pop_woman_10s',
                      "2020년04월_여_거주자_20~29세":'pop_woman_20s',
                      "2020년04월_여_거주자_30~39세":'pop_woman_30s',
                      "2020년04월_여_거주자_40~49세":'pop_woman_40s',
                      "2020년04월_여_거주자_50~59세":'pop_woman_50s',
                      "2020년04월_여_거주자_60~69세":'pop_woman_60s',
                      "2020년04월_여_거주자_70~79세":'pop_woman_70s',
                      "2020년04월_여_거주자_80~89세":'pop_woman_80s',
                      "2020년04월_여_거주자_90~99세":'pop_woman_90s',
                      "2020년04월_여_거주자_100세 이상":'pop_woman_100s',
}, inplace = True)
data1
# Out:
#          pop_0s    pop_10s    pop_20s    pop_30s    pop_40s    pop_50s  \
# 행정구역
# 서울      650,826    803,250  1,451,810  1,483,018  1,524,792  1,499,315
# 부산      239,821    278,455    433,167    425,814    509,466    569,951
# 대구      185,071    232,076    321,484    299,770    386,016    423,834
# 인천      237,418    278,422    403,226    411,277    482,385    507,900
# 광주      124,372    161,479    207,838    189,027    242,383    232,197
# 대전      119,367    150,483    211,659    196,784    238,734    240,239
# 울산      102,565    114,586    146,888    156,252    188,436    209,656
# 세종       47,388     40,869     36,274     61,107     65,852     43,000
# 경기    1,172,075  1,339,379  1,778,526  1,904,165  2,273,048  2,184,218
# 강원      108,045    140,425    178,154    167,408    223,985    265,623
# 충북      127,195    151,801    197,669    196,265    240,481    271,166
# 충남      178,492    205,103    241,970    272,658    325,856    336,295
# ...

# %%
data1.to_csv('C:/Users/USER/Desktop/2020 summer dacon/2020_jeju_credit card/data/시별-연령별,성별 population data.csv', index = False)

# %%
# 물어봐야 할 것 : 시도, 연령
